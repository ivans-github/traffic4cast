# %%
import os
import shutil
import json
import h5py
import tarfile
from fastai.basics import *
from tqdm.notebook import tqdm
from itertools import islice

WORKING_DIR = '../working'
INPUT_DIR = '../input/traffic4cast2020'
MODEL_DIR = '../input/traffic4cast2020models'
MODEL_NAME = 'istanbul_g091_l07_m.pth'

CITIES = ['ISTANBUL']

# %% [markdown]
# # Load test_slots.json

# %%
with open(f'{INPUT_DIR}/test_slots.json', 'r') as json_file:
    test_slots = json.load(json_file)
    test_slots = {k:v for each in test_slots for k,v in each.items()}

# %% [markdown]
# # Load Model

# %%
def ConvLayer(in_channels, out_channels, kernel_size=3, stride=1, padding=1):
    '''Conv2d + ELU'''
    return nn.Sequential(nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding),
                         nn.ELU(inplace=True))

def ConvBlock(in_channels, out_channels, kernel_size=3, stride=1, padding=1):
    '''Conv2d + ELU + GroupNorm'''
    return nn.Sequential(ConvLayer(in_channels, out_channels, kernel_size, stride, padding),
                         nn.GroupNorm(num_groups=8, num_channels=out_channels, eps=1e-6))

####################################################################################################

class DenseBlock(nn.Module):
    def __init__(self, in_channels, out_channels, nb_layers=4):
        super().__init__()
        self.first_layer = ConvBlock(in_channels, out_channels, kernel_size=3, stride=1, padding=1)
        self.mid_layers = nn.ModuleList([ConvBlock(in_channels + i*out_channels, out_channels, kernel_size=3, stride=1, padding=1) 
                                         for i in range(1, nb_layers)])
        self.last_layer = ConvLayer(in_channels + nb_layers*out_channels, out_channels, kernel_size=1, stride=1, padding=0)
        
    def forward(self, x):
        layers_concat = list()
        layers_concat.append(x)
        layers_concat.append(self.first_layer(x))
        
        for mid_layer in self.mid_layers:
            layers_concat.append(mid_layer(torch.cat(layers_concat, dim=1)))
            
        return self.last_layer(torch.cat(layers_concat, dim=1))

def AvgPoolDenseBlock(in_channels, out_channels, nb_layers=4):
    return nn.Sequential(nn.AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=True),
                         DenseBlock(in_channels, out_channels, nb_layers))

class UpConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.convtrans = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=3, stride=2, padding=1)
        self.elu = nn.ELU(inplace=True)
    
    def forward(self, x, x_enc):
        x = self.convtrans(x, output_size=x_enc.shape[-2:])
        x = self.elu(x)
        return torch.cat([x, x_enc], dim=1)

# %%
class NetN(nn.Module):
    def __init__(self, num_in_frames=12, num_out_frames=12):
        super().__init__()
        
        self.enc1 = DenseBlock(9*num_in_frames+3*9+7+1, 64, 4)
        self.enc2 = AvgPoolDenseBlock(64, 96, 4)
        self.enc3 = AvgPoolDenseBlock(96, 128, 4)
        self.enc4 = AvgPoolDenseBlock(128, 128, 4)
        self.enc5 = AvgPoolDenseBlock(128, 128, 4)
        self.enc6 = AvgPoolDenseBlock(128, 128, 4)
        self.enc7 = AvgPoolDenseBlock(128, 128, 4)
        self.enc8 = AvgPoolDenseBlock(128, 128, 4)
        
        self.bridge = ConvBlock(128, 128)
        
        self.dec7_1 = UpConvBlock(128, 128)
        self.dec7_2 = ConvBlock(128+128, 128)
        self.dec6_1 = UpConvBlock(128, 128)
        self.dec6_2 = ConvBlock(128+128, 128)
        self.dec5_1 = UpConvBlock(128, 128)
        self.dec5_2 = ConvBlock(128+128, 128)
        self.dec4_1 = UpConvBlock(128, 128)
        self.dec4_2 = ConvBlock(128+128, 128)
        self.dec3_1 = UpConvBlock(128, 128)
        self.dec3_2 = ConvBlock(128+128, 128)
        self.dec2_1 = UpConvBlock(128, 128)
        self.dec2_2 = ConvBlock(128+96, 128)
        self.dec1_1 = UpConvBlock(128, 128)
        self.dec1_2 = ConvBlock(128+64, 128)
        
        self.out_1 = nn.Conv2d(128, 9*num_out_frames, kernel_size=3, stride=1, padding=1)
        self.out_2 = nn.Sigmoid()
          
    def forward(self, x):
        
        x0 = x[:,:108,...]               # 4, 108, 495, 436
        s = x[:,108:115,...]             # 4, 7, 495, 436
        t = x[:,115,...].unsqueeze(1)    # 4, 1, 495, 436
        
        N, C, H, W = x0.shape            # 4, 108, 495, 436
        x0r = x0.reshape(N, 9, 12, H, W) # 4, 9, 12, 495, 436
        x0_mean = x0r.mean(dim=2)        # 4, 9, 495, 436
        x0_std = x0r.std(dim=2)
        x0_rng = x0r.max(dim=2).values - x0r.min(dim=2).values
        
        x = torch.cat([x0, x0_mean, x0_std, x0_rng, s, t], dim=1)
        x = x / 255.
        
        x1 = self.enc1(x)
        x2 = self.enc2(x1)
        x3 = self.enc3(x2)
        x4 = self.enc4(x3)
        x5 = self.enc5(x4)
        x6 = self.enc6(x5)
        x7 = self.enc7(x6)
        x8 = self.enc8(x7)
        
        x100 = self.bridge(x8)
        
        x107 = self.dec7_2(self.dec7_1(x100, x7))
        x106 = self.dec6_2(self.dec6_1(x107, x6))
        x105 = self.dec5_2(self.dec5_1(x106, x5))
        x104 = self.dec4_2(self.dec4_1(x105, x4))
        x103 = self.dec3_2(self.dec3_1(x104, x3))
        x102 = self.dec2_2(self.dec2_1(x103, x2))
        x101 = self.dec1_2(self.dec1_1(x102, x1))
        
        out = self.out_2(self.out_1(x101))*255.
        return out.view(N, 9, -1, H, W)

# %%
model = NetN().cuda()
state = torch.load(f'{MODEL_DIR}/{MODEL_NAME}')
hasopt = set(state)=={'model', 'opt'}
model_state = state['model'] if hasopt else state
model.load_state_dict(model_state, strict=True)
model.eval()
# Out:
# NetN(
#   (enc1): DenseBlock(
#     (first_layer): Sequential(
#       (0): Sequential(
#         (0): Conv2d(143, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ELU(alpha=1.0, inplace=True)
#       )
#       (1): GroupNorm(8, 64, eps=1e-06, affine=True)
#     )
#     (mid_layers): ModuleList(
#       (0): Sequential(
#         (0): Sequential(
#           (0): Conv2d(207, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ELU(alpha=1.0, inplace=True)
#         )
#         (1): GroupNorm(8, 64, eps=1e-06, affine=True)
#       )
#       (1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(271, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ELU(alpha=1.0, inplace=True)
#         )
#         (1): GroupNorm(8, 64, eps=1e-06, affine=True)
#       )
#       (2): Sequential(
#         (0): Sequential(
#           (0): Conv2d(335, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ELU(alpha=1.0, inplace=True)
#         )
#         (1): GroupNorm(8, 64, eps=1e-06, affine=True)
#       )
#     )
#     (last_layer): Sequential(
#       (0): Conv2d(399, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): ELU(alpha=1.0, inplace=True)
#     )
#   )
#   (enc2): Sequential(
#     (0): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (1): DenseBlock(
#       (first_layer): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ELU(alpha=1.0, inplace=True)
#         )
#         (1): GroupNorm(8, 96, eps=1e-06, affine=True)
#       )
#       (mid_layers): ModuleList(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d(160, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 96, eps=1e-06, affine=True)
#         )
#         (1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(256, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 96, eps=1e-06, affine=True)
#         )
#         (2): Sequential(
#           (0): Sequential(
#             (0): Conv2d(352, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 96, eps=1e-06, affine=True)
#         )
#       )
#       (last_layer): Sequential(
#         (0): Conv2d(448, 96, kernel_size=(1, 1), stride=(1, 1))
#         (1): ELU(alpha=1.0, inplace=True)
#       )
#     )
#   )
#   (enc3): Sequential(
#     (0): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (1): DenseBlock(
#       (first_layer): Sequential(
#         (0): Sequential(
#           (0): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ELU(alpha=1.0, inplace=True)
#         )
#         (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#       )
#       (mid_layers): ModuleList(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d(224, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#         (1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(352, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#         (2): Sequential(
#           (0): Sequential(
#             (0): Conv2d(480, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#       )
#       (last_layer): Sequential(
#         (0): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ELU(alpha=1.0, inplace=True)
#       )
#     )
#   )
#   (enc4): Sequential(
#     (0): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (1): DenseBlock(
#       (first_layer): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ELU(alpha=1.0, inplace=True)
#         )
#         (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#       )
#       (mid_layers): ModuleList(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#         (1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#         (2): Sequential(
#           (0): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#       )
#       (last_layer): Sequential(
#         (0): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ELU(alpha=1.0, inplace=True)
#       )
#     )
#   )
#   (enc5): Sequential(
#     (0): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (1): DenseBlock(
#       (first_layer): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ELU(alpha=1.0, inplace=True)
#         )
#         (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#       )
#       (mid_layers): ModuleList(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#         (1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#         (2): Sequential(
#           (0): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#       )
#       (last_layer): Sequential(
#         (0): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ELU(alpha=1.0, inplace=True)
#       )
#     )
#   )
#   (enc6): Sequential(
#     (0): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (1): DenseBlock(
#       (first_layer): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ELU(alpha=1.0, inplace=True)
#         )
#         (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#       )
#       (mid_layers): ModuleList(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#         (1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#         (2): Sequential(
#           (0): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#       )
#       (last_layer): Sequential(
#         (0): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ELU(alpha=1.0, inplace=True)
#       )
#     )
#   )
#   (enc7): Sequential(
#     (0): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (1): DenseBlock(
#       (first_layer): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ELU(alpha=1.0, inplace=True)
#         )
#         (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#       )
#       (mid_layers): ModuleList(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#         (1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#         (2): Sequential(
#           (0): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#       )
#       (last_layer): Sequential(
#         (0): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ELU(alpha=1.0, inplace=True)
#       )
#     )
#   )
#   (enc8): Sequential(
#     (0): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (1): DenseBlock(
#       (first_layer): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ELU(alpha=1.0, inplace=True)
#         )
#         (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#       )
#       (mid_layers): ModuleList(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#         (1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#         (2): Sequential(
#           (0): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ELU(alpha=1.0, inplace=True)
#           )
#           (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#         )
#       )
#       (last_layer): Sequential(
#         (0): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ELU(alpha=1.0, inplace=True)
#       )
#     )
#   )
#   (bridge): Sequential(
#     (0): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ELU(alpha=1.0, inplace=True)
#     )
#     (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#   )
#   (dec7_1): UpConvBlock(
#     (convtrans): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (elu): ELU(alpha=1.0, inplace=True)
#   )
#   (dec7_2): Sequential(
#     (0): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ELU(alpha=1.0, inplace=True)
#     )
#     (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#   )
#   (dec6_1): UpConvBlock(
#     (convtrans): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (elu): ELU(alpha=1.0, inplace=True)
#   )
#   (dec6_2): Sequential(
#     (0): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ELU(alpha=1.0, inplace=True)
#     )
#     (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#   )
#   (dec5_1): UpConvBlock(
#     (convtrans): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (elu): ELU(alpha=1.0, inplace=True)
#   )
#   (dec5_2): Sequential(
#     (0): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ELU(alpha=1.0, inplace=True)
#     )
#     (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#   )
#   (dec4_1): UpConvBlock(
#     (convtrans): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (elu): ELU(alpha=1.0, inplace=True)
#   )
#   (dec4_2): Sequential(
#     (0): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ELU(alpha=1.0, inplace=True)
#     )
#     (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#   )
#   (dec3_1): UpConvBlock(
#     (convtrans): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (elu): ELU(alpha=1.0, inplace=True)
#   )
#   (dec3_2): Sequential(
#     (0): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ELU(alpha=1.0, inplace=True)
#     )
#     (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#   )
#   (dec2_1): UpConvBlock(
#     (convtrans): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (elu): ELU(alpha=1.0, inplace=True)
#   )
#   (dec2_2): Sequential(
#     (0): Sequential(
#       (0): Conv2d(224, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ELU(alpha=1.0, inplace=True)
#     )
#     (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#   )
#   (dec1_1): UpConvBlock(
#     (convtrans): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (elu): ELU(alpha=1.0, inplace=True)
#   )
#   (dec1_2): Sequential(
#     (0): Sequential(
#       (0): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ELU(alpha=1.0, inplace=True)
#     )
#     (1): GroupNorm(8, 128, eps=1e-06, affine=True)
#   )
#   (out_1): Conv2d(128, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (out_2): Sigmoid()
# )

# %% [markdown]
# # Create Submission

# %%
# Clear working directory
# !rm -r *

for city in CITIES:
    
    print(city)
    working_path = Path(f'{WORKING_DIR}/{city}')
    
    # Unzip data if it is not already done so
    if not working_path.exists():
        with tarfile.open(f'{INPUT_DIR}/{city}.tar') as tarred_file:
            files = [tarinfo for tarinfo in tarred_file.getmembers()
                     if tarinfo.name.startswith(f'{city}/testing/')
                     or tarinfo.name.startswith(f'{city}/{city}_static')] # Only unzipping the testing folder and static file
            tarred_file.extractall(members=files, path=WORKING_DIR)
    
    # load static features
    with h5py.File(f'{working_path}/{city}_static_2019.h5', 'r') as static_file:
        static_features = static_file.get('array')[()].astype(np.float32)
        static_features = torch.from_numpy(static_features).permute(2, 0, 1)
    static_features = static_features
    
    # Loop through each test date
    for date, frame in tqdm(test_slots.items()): #for date in tqdm(list(islice(test_slots, 3))):
        
        with h5py.File(f'{working_path}/testing/{date}_test.h5', 'r') as h5_file:
            x = h5_file.get('array')[()]
            
        # Note dimension reordering, from (Batch Size, Time, Height, Width, Channels) to (Batch Size, Channels, Time, Height, Width)
        x = np.transpose(x, (0, 4, 1, 2, 3))
        x = torch.from_numpy(x).float()
            
        ##################################################################################################
        # Calculate output
        with torch.no_grad():

            N, C, D, H, W = x.shape
            x = x.reshape(N, C*D, H, W)
            s = torch.stack(N*[static_features], dim=0)
            t = torch.ones(N, 1, H, W)
            for j in range(N):
                t[j] = t[j] * frame[j] * 255. / (288. - 12)
            x = torch.cat([x, s, t], dim=1)
                
            if x.shape[0] > 3:
                y1 = model(x[:3].cuda()).cpu()
                y2 = model(x[3:].cuda()).cpu()
                y = torch.cat([y1, y2])
                del y1, y2
            else:
                y = model(x.cuda()).cpu()
            
            y = torch.round(y)
            y = torch.clamp(y, min=0, max=255)
        ##################################################################################################
        
        # Dimension reordering
        y = y.permute(0, 2, 3, 4, 1).byte()
        # Assume output.shape == input.shape, hence slice out the bit required for submission
        y = y[:,[0,1,2,5,8,11],:,:,:8]
        
        with h5py.File(f'{working_path}/{date}_test.h5', 'w') as h5_file:
            h5_file.create_dataset('array', data=y, compression="gzip", compression_opts=6)
            
        del x, y
        torch.cuda.empty_cache()
        
        # Delete the used files to save disk space...
        os.remove(f'{working_path}/testing/{date}_test.h5')
        
    # Delete data folder
    shutil.rmtree(f'{working_path}/testing')
    os.remove(f'{working_path}/{city}_static_2019.h5')

# Create .zip file
# !zip -r0 submission.zip .
# Out:
# ISTANBUL
# HBox(children=(FloatProgress(value=0.0, max=163.0), HTML(value='')))
#   adding: __notebook__.ipynb (stored 0%)
#   adding: ISTANBUL/ (stored 0%)
#   adding: ISTANBUL/2019-07-28_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-28_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-04_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-01_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-22_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-30_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-29_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-11_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-24_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-27_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-06_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-02_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-08_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-24_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-12_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-15_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-03_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-13_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-17_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-29_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-12_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-17_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-25_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-10_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-02_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-03_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-20_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-03_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-11_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-15_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-19_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-10_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-23_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-13_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-13_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-04_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-07_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-26_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-27_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-19_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-07_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-17_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-28_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-26_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-26_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-31_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-25_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-16_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-14_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-07_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-09_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-02_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-09_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-08_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-22_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-15_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-12_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-04_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-14_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-05_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-05_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-08_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-24_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-02_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-30_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-03_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-05_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-23_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-16_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-25_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-21_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-21_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-14_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-06_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-22_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-14_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-01_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-16_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-30_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-10_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-23_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-09_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-09_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-18_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-08_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-27_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-25_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-26_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-06_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-31_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-27_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-17_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-15_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-10_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-04_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-07_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-14_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-11_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-12_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-05_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-19_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-24_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-24_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-11_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-23_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-21_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-15_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-22_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-26_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-06_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-18_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-12_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-23_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-10_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-03_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-24_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-14_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-26_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-28_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-04_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-06_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-12_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-13_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-20_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-29_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-28_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-29_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-02_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-13_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-03_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-23_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-30_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-20_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-27_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-01_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-31_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-18_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-18_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-05_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-01_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-07_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-20_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-27_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-20_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-25_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-15_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-17_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-02_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-11_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-21_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-16_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-30_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-16_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-21_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-17_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-08-25_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-11-19_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-09-07_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-01_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-07-16_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-10-22_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-13_test.h5 (stored 0%)
#   adding: ISTANBUL/2019-12-22_test.h5 (stored 0%)

# %%
# !zip -d submission *.ipynb
# Out:
# deleting: __notebook__.ipynb
